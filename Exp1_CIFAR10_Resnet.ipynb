# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense
from tensorflow.keras.applications import ResNet50
from tensorflow.keras import layers, models
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns

# Ensure TensorFlow is set up correctly
assert tf.__version__ >= "2.0", "This code requires TensorFlow 2.0 or higher."

# Set random seeds for reproducibility
tf.random.set_seed(42)
np.random.seed(42)

# Constants
INPUT_SHAPE = (32, 32, 3)
NUM_CLASSES = 10
BATCH_SIZE = 64
EPOCHS = 50
LEARNING_RATE = 0.0001

def load_and_preprocess_data():
    """
    Loads the CIFAR-10 dataset and preprocesses it for training.
    """
    (x_train, y_train), (x_test, y_test) = cifar10.load_data()

    # Normalize the images to [0, 1] range
    x_train = x_train.astype('float32') / 255.0
    x_test = x_test.astype('float32') / 255.0

    # One-hot encode the labels
    y_train = to_categorical(y_train, NUM_CLASSES)
    y_test = to_categorical(y_test, NUM_CLASSES)

    return x_train, y_train, x_test, y_test

def build_model(input_shape, num_classes):
    """
    Builds a CNN model using a pretrained ResNet50 for CIFAR-10 classification.

    Args:
        input_shape (tuple): Shape of the input images.
        num_classes (int): Number of classes in the dataset.

    Returns:
        model (Sequential): Compiled Keras model.
    """
    # Load the pretrained ResNet50 model
    base_model = ResNet50(
        weights='imagenet',
        include_top=False,
        input_shape=input_shape
    )

    # Freeze all layers initially
    for layer in base_model.layers:
        layer.trainable = False

    # Unfreeze layers starting from the 164th layer, excluding Batch Normalization layers
    for layer in base_model.layers[164:]:
        if not isinstance(layer, layers.BatchNormalization):
            layer.trainable = True

    # Create the full model
    model = models.Sequential([
        base_model,
        GlobalAveragePooling2D(),
        Dense(num_classes, activation='softmax')
    ])

    # Compile the model
    model.compile(optimizer=Adam(learning_rate=LEARNING_RATE),
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])

    return model

def get_callbacks():
    """
    Returns a list of callbacks for training.

    Returns:
        list: List of Keras callbacks.
    """
    early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
    model_saver = ModelCheckpoint('best_resnet_model_cifar10.keras', monitor='val_accuracy', mode='max', save_best_only=True)
    reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, verbose=1)

    return [early_stopping, model_saver, reduce_lr]

def train_model(model, x_train, y_train, x_val, y_val, batch_size, epochs):
    """
    Trains the CNN model on the training data.

    Args:
        model (Sequential): Keras model to be trained.
        x_train (numpy.array): Training images.
        y_train (numpy.array): Training labels.
        x_val (numpy.array): Validation images.
        y_val (numpy.array): Validation labels.
        batch_size (int): Batch size for training.
        epochs (int): Number of epochs for training.

    Returns:
        history: Training history object.
    """
    callbacks = get_callbacks()

    history = model.fit(x_train, y_train,
                        validation_data=(x_val, y_val),
                        batch_size=batch_size,
                        epochs=epochs,
                        callbacks=callbacks,
                        verbose=1)

    return history

def evaluate_model(model, x_test, y_test):
    """
    Evaluates the trained model on the test data.

    Args:
        model (Sequential): Trained Keras model.
        x_test (numpy.array): Test images.
        y_test (numpy.array): Test labels.

    Returns:
        loss (float): Test loss.
        accuracy (float): Test accuracy.
    """
    loss, accuracy = model.evaluate(x_test, y_test, verbose=0)
    print(f"Test loss: {loss:.4f}")
    print(f"Test accuracy: {accuracy:.4f}")

    return loss, accuracy

# Load and preprocess data
x_train, y_train, x_test, y_test = load_and_preprocess_data()

# Split the training data into training and validation sets
x_val, y_val = x_train[-10000:], y_train[-10000:]
x_train, y_train = x_train[:-10000], y_train[:-10000]

# Build the model
model = build_model(INPUT_SHAPE, NUM_CLASSES)

# Train the model
history = train_model(model, x_train, y_train, x_val, y_val, BATCH_SIZE, EPOCHS)

# Evaluate the model on the test set
evaluate_model(model, x_test, y_test)

# Function to plot training and validation curves
def plot_training_history(history):
    # Plot accuracy
    plt.figure(figsize=(14, 5))
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'], label='Train Accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.title('Accuracy over Epochs')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend(loc='upper left')

    # Plot loss
    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title('Loss over Epochs')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend(loc='upper right')

    plt.show()

# Call the plot function after training
plot_training_history(history)

# Load the saved model
model = load_model('best_resnet_model_cifar10.keras')

# Load CIFAR-10 test dataset
(_, _), (X_test, Y_test) = cifar10.load_data()

# Normalize the test data
X_test = X_test.astype('float32') / 255.0
Y_test_one_hot = to_categorical(Y_test, NUM_CLASSES)  # One-hot encode the labels

# Evaluate the model on test data
test_loss, test_accuracy = model.evaluate(X_test, Y_test_one_hot, verbose=1)

# Print the evaluation metrics
print(f"Test Loss: {test_loss:.4f}")
print(f"Test Accuracy: {test_accuracy:.4f}")

# Get predictions for the confusion matrix
Y_pred = model.predict(X_test)
Y_pred_classes = np.argmax(Y_pred, axis=1)  # Convert one-hot predictions to class labels

# Confusion Matrix
conf_matrix = confusion_matrix(Y_test, Y_pred_classes)

# Plot the confusion matrix using seaborn heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=range(10), yticklabels=range(10))
plt.title('Confusion Matrix')
plt.ylabel('True Label')
plt.xlabel('Predicted Label')
plt.show()

# Classification report for precision, recall, f1-score for each class
print("\nClassification Report:\n", classification_report(Y_test, Y_pred_classes))
# Out:
# 2024-11-02 15:08:30.554396: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1730556510.569579   52924 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1730556510.574058   52924 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-11-02 15:08:30.591746: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# I0000 00:00:1730556514.528185   52924 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 2172 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3050 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6
# Epoch 1/50
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1730556520.801337   53020 service.cc:148] XLA service 0x7895c4003400 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1730556520.801369   53020 service.cc:156]   StreamExecutor device (0): NVIDIA GeForce RTX 3050 Laptop GPU, Compute Capability 8.6
# 2024-11-02 15:08:40.925245: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1730556521.598275   53020 cuda_dnn.cc:529] Loaded cuDNN version 90300
# 2024-11-02 15:08:42.333125: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_6160', 4 bytes spill stores, 4 bytes spill loads
#
# 2024-11-02 15:08:42.469178: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_3237', 92 bytes spill stores, 92 bytes spill loads
#
# 2024-11-02 15:08:42.553697: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_3237', 384 bytes spill stores, 384 bytes spill loads
#  18/625 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.1045 - loss: 2.6308
# I0000 00:00:1730556525.933746   53020 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 622/625 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.1678 - loss: 2.2421
# 2024-11-02 15:08:56.398431: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1708', 92 bytes spill stores, 92 bytes spill loads
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 22s 22ms/step - accuracy: 0.1681 - loss: 2.2413 - val_accuracy: 0.2991 - val_loss: 1.9364 - learning_rate: 1.0000e-04
# Epoch 2/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.2952 - loss: 1.9336 - val_accuracy: 0.3264 - val_loss: 1.8464 - learning_rate: 1.0000e-04
# Epoch 3/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.3246 - loss: 1.8595 - val_accuracy: 0.3494 - val_loss: 1.7991 - learning_rate: 1.0000e-04
# Epoch 4/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.3454 - loss: 1.8083 - val_accuracy: 0.3626 - val_loss: 1.7655 - learning_rate: 1.0000e-04
# Epoch 5/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.3617 - loss: 1.7704 - val_accuracy: 0.3738 - val_loss: 1.7373 - learning_rate: 1.0000e-04
# Epoch 6/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 12ms/step - accuracy: 0.3731 - loss: 1.7395 - val_accuracy: 0.3848 - val_loss: 1.7142 - learning_rate: 1.0000e-04
# Epoch 7/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 12ms/step - accuracy: 0.3840 - loss: 1.7144 - val_accuracy: 0.3909 - val_loss: 1.6906 - learning_rate: 1.0000e-04
# Epoch 8/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 12ms/step - accuracy: 0.3916 - loss: 1.6956 - val_accuracy: 0.3977 - val_loss: 1.6739 - learning_rate: 1.0000e-04
# Epoch 9/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 12ms/step - accuracy: 0.3962 - loss: 1.6795 - val_accuracy: 0.4020 - val_loss: 1.6617 - learning_rate: 1.0000e-04
# Epoch 10/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.4027 - loss: 1.6659 - val_accuracy: 0.4028 - val_loss: 1.6527 - learning_rate: 1.0000e-04
# Epoch 11/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 12ms/step - accuracy: 0.4087 - loss: 1.6529 - val_accuracy: 0.4086 - val_loss: 1.6453 - learning_rate: 1.0000e-04
# Epoch 12/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 12ms/step - accuracy: 0.4138 - loss: 1.6416 - val_accuracy: 0.4137 - val_loss: 1.6345 - learning_rate: 1.0000e-04
# Epoch 13/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.4170 - loss: 1.6292 - val_accuracy: 0.4141 - val_loss: 1.6295 - learning_rate: 1.0000e-04
# Epoch 14/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - accuracy: 0.4203 - loss: 1.6183 - val_accuracy: 0.4137 - val_loss: 1.6288 - learning_rate: 1.0000e-04
# Epoch 15/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.4244 - loss: 1.6069 - val_accuracy: 0.4243 - val_loss: 1.6067 - learning_rate: 1.0000e-04
# Epoch 16/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 12ms/step - accuracy: 0.4287 - loss: 1.5969 - val_accuracy: 0.4201 - val_loss: 1.6026 - learning_rate: 1.0000e-04
# Epoch 17/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.4342 - loss: 1.5865 - val_accuracy: 0.4247 - val_loss: 1.6028 - learning_rate: 1.0000e-04
# Epoch 18/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.4367 - loss: 1.5768 - val_accuracy: 0.4270 - val_loss: 1.5966 - learning_rate: 1.0000e-04
# Epoch 19/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.4420 - loss: 1.5674 - val_accuracy: 0.4274 - val_loss: 1.5883 - learning_rate: 1.0000e-04
# Epoch 20/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.4458 - loss: 1.5557 - val_accuracy: 0.4363 - val_loss: 1.5739 - learning_rate: 1.0000e-04
# Epoch 21/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.4480 - loss: 1.5482 - val_accuracy: 0.4334 - val_loss: 1.5827 - learning_rate: 1.0000e-04
# Epoch 22/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - accuracy: 0.4511 - loss: 1.5392 - val_accuracy: 0.4286 - val_loss: 1.5925 - learning_rate: 1.0000e-04
# Epoch 23/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - accuracy: 0.4545 - loss: 1.5318 - val_accuracy: 0.4333 - val_loss: 1.5861 - learning_rate: 1.0000e-04
# Epoch 24/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - accuracy: 0.4551 - loss: 1.5264 - val_accuracy: 0.4323 - val_loss: 1.5828 - learning_rate: 1.0000e-04
# Epoch 25/50
# 620/625 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.4592 - loss: 1.5165
# Epoch 25: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - accuracy: 0.4592 - loss: 1.5166 - val_accuracy: 0.4300 - val_loss: 1.5892 - learning_rate: 1.0000e-04
# Epoch 26/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.4697 - loss: 1.4812 - val_accuracy: 0.4655 - val_loss: 1.5161 - learning_rate: 5.0000e-05
# Epoch 27/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - accuracy: 0.4750 - loss: 1.4693 - val_accuracy: 0.4640 - val_loss: 1.5141 - learning_rate: 5.0000e-05
# Epoch 28/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - accuracy: 0.4779 - loss: 1.4618 - val_accuracy: 0.4636 - val_loss: 1.5127 - learning_rate: 5.0000e-05
# Epoch 29/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.4817 - loss: 1.4546 - val_accuracy: 0.4645 - val_loss: 1.5136 - learning_rate: 5.0000e-05
# Epoch 30/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - accuracy: 0.4858 - loss: 1.4471 - val_accuracy: 0.4626 - val_loss: 1.5106 - learning_rate: 5.0000e-05
# Epoch 31/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.4870 - loss: 1.4406 - val_accuracy: 0.4630 - val_loss: 1.5094 - learning_rate: 5.0000e-05
# Epoch 32/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - accuracy: 0.4894 - loss: 1.4340 - val_accuracy: 0.4634 - val_loss: 1.5109 - learning_rate: 5.0000e-05
# Epoch 33/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - accuracy: 0.4920 - loss: 1.4276 - val_accuracy: 0.4646 - val_loss: 1.5085 - learning_rate: 5.0000e-05
# Epoch 34/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.4939 - loss: 1.4213 - val_accuracy: 0.4646 - val_loss: 1.5042 - learning_rate: 5.0000e-05
# Epoch 35/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.4963 - loss: 1.4151 - val_accuracy: 0.4664 - val_loss: 1.5014 - learning_rate: 5.0000e-05
# Epoch 36/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.4991 - loss: 1.4085 - val_accuracy: 0.4674 - val_loss: 1.4990 - learning_rate: 5.0000e-05
# Epoch 37/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.5018 - loss: 1.4023 - val_accuracy: 0.4654 - val_loss: 1.5013 - learning_rate: 5.0000e-05
# Epoch 38/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - accuracy: 0.5022 - loss: 1.3965 - val_accuracy: 0.4670 - val_loss: 1.4987 - learning_rate: 5.0000e-05
# Epoch 39/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.5055 - loss: 1.3911 - val_accuracy: 0.4681 - val_loss: 1.4998 - learning_rate: 5.0000e-05
# Epoch 40/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.5092 - loss: 1.3835 - val_accuracy: 0.4696 - val_loss: 1.4985 - learning_rate: 5.0000e-05
# Epoch 41/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - accuracy: 0.5101 - loss: 1.3786 - val_accuracy: 0.4717 - val_loss: 1.4958 - learning_rate: 5.0000e-05
# Epoch 42/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 13s 21ms/step - accuracy: 0.5100 - loss: 1.3722 - val_accuracy: 0.4721 - val_loss: 1.4956 - learning_rate: 5.0000e-05
# Epoch 43/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 9s 14ms/step - accuracy: 0.5142 - loss: 1.3664 - val_accuracy: 0.4704 - val_loss: 1.4994 - learning_rate: 5.0000e-05
# Epoch 44/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 14s 22ms/step - accuracy: 0.5174 - loss: 1.3610 - val_accuracy: 0.4741 - val_loss: 1.4987 - learning_rate: 5.0000e-05
# Epoch 45/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 13s 22ms/step - accuracy: 0.5191 - loss: 1.3542 - val_accuracy: 0.4729 - val_loss: 1.5007 - learning_rate: 5.0000e-05
# Epoch 46/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 13s 21ms/step - accuracy: 0.5209 - loss: 1.3486 - val_accuracy: 0.4764 - val_loss: 1.4996 - learning_rate: 5.0000e-05
# Epoch 47/50
# 624/625 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.5242 - loss: 1.3421
# Epoch 47: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 12s 20ms/step - accuracy: 0.5242 - loss: 1.3422 - val_accuracy: 0.4755 - val_loss: 1.5016 - learning_rate: 5.0000e-05
# Epoch 48/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 13s 21ms/step - accuracy: 0.5255 - loss: 1.3386 - val_accuracy: 0.4812 - val_loss: 1.4917 - learning_rate: 2.5000e-05
# Epoch 49/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 13s 21ms/step - accuracy: 0.5264 - loss: 1.3339 - val_accuracy: 0.4825 - val_loss: 1.4897 - learning_rate: 2.5000e-05
# Epoch 50/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 13s 21ms/step - accuracy: 0.5294 - loss: 1.3282 - val_accuracy: 0.4840 - val_loss: 1.4865 - learning_rate: 2.5000e-05
# 2024-11-02 15:16:05.868354: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1708', 92 bytes spill stores, 92 bytes spill loads
#
# 2024-11-02 15:16:05.920659: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1708', 384 bytes spill stores, 384 bytes spill loads
# Test loss: 1.4958
# Test accuracy: 0.4747
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 13ms/step - accuracy: 0.4765 - loss: 1.4901
# Test Loss: 1.4958
# Test Accuracy: 0.4747
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 8s 16ms/step
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.54      0.61      0.57      1000
#            1       0.52      0.55      0.53      1000
#            2       0.41      0.28      0.33      1000
#            3       0.38      0.18      0.24      1000
#            4       0.44      0.38      0.41      1000
#            5       0.43      0.42      0.43      1000
#            6       0.50      0.56      0.53      1000
#            7       0.44      0.62      0.51      1000
#            8       0.55      0.58      0.56      1000
#            9       0.47      0.57      0.51      1000
#
#     accuracy                           0.47     10000
#    macro avg       0.47      0.47      0.46     10000
# weighted avg       0.47      0.47      0.46     10000
